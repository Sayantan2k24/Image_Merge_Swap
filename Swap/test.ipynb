# %%
import matplotlib.pyplot as plt
import cv2

Tai_lung = cv2.imread("image1.png")

plt.imshow(Tai_lung)
print(Tai_lung.shape)
# Out:
# (432, 768, 3)

# %%
Tai_cropped_face = Tai_lung[10:350 , 280:620]
plt.imshow(Tai_cropped_face)
print(Tai_cropped_face.shape)
# Out:
# (340, 340, 3)

# %%
import matplotlib.pyplot as plt
import cv2

poo= cv2.imread("image2.png")

plt.imshow(poo)
print(poo.shape)
# Out:
# (900, 1600, 3)

# %%
print(Tai_cropped_face.shape[0])
print(Tai_cropped_face.shape[1])
# Out:
# 340
# 340

# %%
poo_cropped_face = poo[50:600 , 560:1200]
plt.imshow(poo_cropped_face)
print(poo_cropped_face.shape)
# Out:
# (550, 640, 3)

# %%
#resized_img = cv2.resize(poo_cropped_face, (340, 340))
resized_img = cv2.resize(poo_cropped_face,(Tai_cropped_face.shape[0],Tai_cropped_face.shape[1]))
plt.imshow(resized_img)
